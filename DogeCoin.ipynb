# %% [markdown]
# <a href="https://colab.research.google.com/github/arocafuertee/arocafuertee.github.io/blob/main/DogeCoin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import regression
sns.set()
plt.style.use('seaborn-whitegrid')

data = pd.read_csv("DOGE-USD.csv")
print(data.head())
# Out:
#          Date      Open      High       Low     Close  Adj Close       Volume
# 0  2020-07-01  0.002320  0.002376  0.002301  0.002354   0.002354  152549214.0
# 1  2020-07-02  0.002330  0.002382  0.002302  0.002361   0.002361  110789127.0
# 2  2020-07-03  0.002361  0.002366  0.002304  0.002316   0.002316  111575143.0
# 3  2020-07-04  0.002315  0.002340  0.002289  0.002309   0.002309  109218071.0
# 4  2020-07-05  0.002307  0.002327  0.002277  0.002309   0.002309  110140542.0

# %%
data.dropna()
plt.figure(figsize=(10, 4))
plt.title("DogeCoin Price INR")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
pip install autots
# Out:
# Collecting autots
#   Downloading https://files.pythonhosted.org/packages/37/04/cd3cdd57d8f27394f6d86f5facc827eabb691b290dc63abb40e3f687163b/AutoTS-0.3.1-py3-none-any.whl (390kB)
#      |████████████████████████████████| 399kB 4.1MB/s
# Requirement already satisfied: statsmodels>=0.10.* in /usr/local/lib/python3.7/dist-packages (from autots) (0.10.2)
# Requirement already satisfied: scikit-learn>=0.20.* in /usr/local/lib/python3.7/dist-packages (from autots) (0.22.2.post1)
# Requirement already satisfied: pandas>=0.25.* in /usr/local/lib/python3.7/dist-packages (from autots) (1.1.5)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from autots) (1.19.5)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.10.*->autots) (1.4.1)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.10.*->autots) (0.5.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.*->autots) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.*->autots) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.*->autots) (2018.9)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.4.0->statsmodels>=0.10.*->autots) (1.15.0)
# Installing collected packages: autots
# Successfully installed autots-0.3.1

# %%
from autots import AutoTS
model = AutoTS(forecast_length=10, frequency='infer', ensemble='simple', drop_data_older_than_periods=200)
model = model.fit(data, date_col='Date', value_col='Close', id_col=None)

prediction = model.predict()
forecast = prediction.forecast
print("DogeCoin Price Prediction")
print(forecast)
# Out:
# Inferred frequency is: D
# Old data dropped by `drop_data_older_than_periods`.
# Model Number: 1 with model AverageValueNaive in generation 0 of 5
# Model Number: 2 with model AverageValueNaive in generation 0 of 5
# Model Number: 3 with model AverageValueNaive in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 3: AverageValueNaive
# Model Number: 4 with model DatepartRegression in generation 0 of 5
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
# Model Number: 5 with model DatepartRegression in generation 0 of 5
# Model Number: 6 with model DatepartRegression in generation 0 of 5
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:470: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Model Number: 7 with model DatepartRegression in generation 0 of 5
# Epoch 1/50
# 6/6 [==============================] - 4s 5ms/step - loss: 0.4298
# Epoch 2/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4258
# Epoch 3/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4182
# Epoch 4/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3941
# Epoch 5/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3892
# Epoch 6/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3786
# Epoch 7/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3614
# Epoch 8/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3494
# Epoch 9/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3283
# Epoch 10/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3125
# Epoch 11/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2838
# Epoch 12/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2649
# Epoch 13/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2409
# Epoch 14/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2188
# Epoch 15/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2021
# Epoch 16/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1992
# Epoch 17/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1814
# Epoch 18/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1762
# Epoch 19/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1734
# Epoch 20/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1624
# Epoch 21/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1487
# Epoch 22/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1569
# Epoch 23/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1442
# Epoch 24/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1613
# Epoch 25/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1508
# Epoch 26/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1477
# Epoch 27/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1483
# Epoch 28/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1339
# Epoch 29/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1428
# Epoch 30/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1266
# Epoch 31/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1287
# Epoch 32/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1245
# Epoch 33/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1286
# Epoch 34/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1295
# Epoch 35/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1316
# Epoch 36/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1246
# Epoch 37/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1339
# Epoch 38/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1250
# Epoch 39/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1183
# Epoch 40/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1150
# Epoch 41/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1156
# Epoch 42/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1223
# Epoch 43/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1110
# Epoch 44/50
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1166
# Epoch 45/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1191
# Epoch 46/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1120
# Epoch 47/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1136
# Epoch 48/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1078
# Epoch 49/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1081
# Epoch 50/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1044
# Model Number: 8 with model ETS in generation 0 of 5
# Model Number: 9 with model ETS in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 9: ETS
# Model Number: 10 with model GLM in generation 0 of 5
# Model Number: 11 with model GLM in generation 0 of 5
# Model Number: 12 with model GLS in generation 0 of 5
# Model Number: 13 with model GLS in generation 0 of 5
# Model Number: 14 with model GluonTS in generation 0 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 14: GluonTS
# Model Number: 15 with model GluonTS in generation 0 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 15: GluonTS
# Model Number: 16 with model GluonTS in generation 0 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 16: GluonTS
# Model Number: 17 with model GluonTS in generation 0 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 17: GluonTS
# Model Number: 18 with model GluonTS in generation 0 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 18: GluonTS
# Model Number: 19 with model GluonTS in generation 0 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 19: GluonTS
# Model Number: 20 with model LastValueNaive in generation 0 of 5
# Model Number: 21 with model LastValueNaive in generation 0 of 5
# Model Number: 22 with model LastValueNaive in generation 0 of 5
# Model Number: 23 with model LastValueNaive in generation 0 of 5
# Model Number: 24 with model SeasonalNaive in generation 0 of 5
# Model Number: 25 with model SeasonalNaive in generation 0 of 5
# Model Number: 26 with model SeasonalNaive in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 26: SeasonalNaive
# Model Number: 27 with model SeasonalNaive in generation 0 of 5
# Model Number: 28 with model UnobservedComponents in generation 0 of 5
# Model Number: 29 with model UnobservedComponents in generation 0 of 5
# Model Number: 30 with model UnobservedComponents in generation 0 of 5
# Model Number: 31 with model VAR in generation 0 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 31: VAR
# Model Number: 32 with model VAR in generation 0 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 32: VAR
# Model Number: 33 with model VAR in generation 0 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 33: VAR
# Model Number: 34 with model VECM in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 34: VECM
# Model Number: 35 with model VECM in generation 0 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 35: VECM
# Model Number: 36 with model VECM in generation 0 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 36: VECM
# Model Number: 37 with model VECM in generation 0 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 37: VECM
# Model Number: 38 with model WindowRegression in generation 0 of 5
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:470: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Model Number: 39 with model ZeroesNaive in generation 0 of 5
# Model Number: 40 with model DatepartRegression in generation 0 of 5
# Template Eval Error: LightGBMError('Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 28 .\n') in model 40: DatepartRegression
# Model Number: 41 with model WindowRegression in generation 0 of 5
# Model Number: 42 with model VAR in generation 0 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 42: VAR
# Model Number: 43 with model AverageValueNaive in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 43: AverageValueNaive
# Model Number: 44 with model AverageValueNaive in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 44: AverageValueNaive
# Model Number: 45 with model UnobservedComponents in generation 0 of 5
# Model Number: 46 with model FBProphet in generation 0 of 5
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 47 with model GLS in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 47: GLS
# Model Number: 48 with model FBProphet in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 48: FBProphet
# Model Number: 49 with model AverageValueNaive in generation 0 of 5
# Model Number: 50 with model AverageValueNaive in generation 0 of 5
# Model Number: 51 with model VAR in generation 0 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 51: VAR
# Model Number: 52 with model FBProphet in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 52: FBProphet
# Model Number: 53 with model AverageValueNaive in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 53: AverageValueNaive
# Model Number: 54 with model SeasonalNaive in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 54: SeasonalNaive
# Model Number: 55 with model GLM in generation 0 of 5
# Model Number: 56 with model DatepartRegression in generation 0 of 5
# Model Number: 57 with model GluonTS in generation 0 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 57: GluonTS
# Model Number: 58 with model WindowRegression in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 58: WindowRegression
# Model Number: 59 with model AverageValueNaive in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 59: AverageValueNaive
# Model Number: 60 with model ETS in generation 0 of 5
# Model Number: 61 with model AverageValueNaive in generation 0 of 5
# Model Number: 62 with model VECM in generation 0 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 62: VECM
# Model Number: 63 with model UnobservedComponents in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 63: UnobservedComponents
# Model Number: 64 with model LastValueNaive in generation 0 of 5
# Model Number: 65 with model ETS in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 65: ETS
# Model Number: 66 with model AverageValueNaive in generation 0 of 5
# Model Number: 67 with model GLS in generation 0 of 5
# Model Number: 68 with model UnobservedComponents in generation 0 of 5
# Model Number: 69 with model GLM in generation 0 of 5
# Model Number: 70 with model FBProphet in generation 0 of 5
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 71 with model GluonTS in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 71: GluonTS
# Model Number: 72 with model VECM in generation 0 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 72: VECM
# Model Number: 73 with model GLM in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 73: GLM
# Model Number: 74 with model ETS in generation 0 of 5
# Model Number: 75 with model WindowRegression in generation 0 of 5
# [LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear]
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
# [LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear]
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
# [LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear]Model Number: 76 with model SeasonalNaive in generation 0 of 5
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
# Model Number: 77 with model AverageValueNaive in generation 0 of 5
# Model Number: 78 with model VECM in generation 0 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 78: VECM
# Model Number: 79 with model VECM in generation 0 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 79: VECM
# New Generation: 1 of 5
# Model Number: 80 with model AverageValueNaive in generation 1 of 5
# Model Number: 81 with model AverageValueNaive in generation 1 of 5
# /usr/local/lib/python3.7/dist-packages/autots/models/sklearn.py:376: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# Model Number: 82 with model AverageValueNaive in generation 1 of 5
# Model Number: 83 with model ETS in generation 1 of 5
# Model Number: 84 with model ETS in generation 1 of 5
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/holtwinters.py:712: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.
# Model Number: 85 with model ETS in generation 1 of 5
# Model Number: 86 with model ETS in generation 1 of 5
# Model Number: 87 with model GLS in generation 1 of 5
# Model Number: 88 with model GLS in generation 1 of 5
# Model Number: 89 with model GLS in generation 1 of 5
# Model Number: 90 with model LastValueNaive in generation 1 of 5
# Model Number: 91 with model LastValueNaive in generation 1 of 5
# Model Number: 92 with model LastValueNaive in generation 1 of 5
# Model Number: 93 with model SeasonalNaive in generation 1 of 5
# Model Number: 94 with model SeasonalNaive in generation 1 of 5
# Model Number: 95 with model SeasonalNaive in generation 1 of 5
# Model Number: 96 with model SeasonalNaive in generation 1 of 5
# Model Number: 97 with model WindowRegression in generation 1 of 5
# Model Number: 98 with model WindowRegression in generation 1 of 5
# Model Number: 99 with model WindowRegression in generation 1 of 5
# Model Number: 100 with model WindowRegression in generation 1 of 5
# Model Number: 101 with model UnobservedComponents in generation 1 of 5
# Model Number: 102 with model UnobservedComponents in generation 1 of 5
# Model Number: 103 with model UnobservedComponents in generation 1 of 5
# Model Number: 104 with model GLM in generation 1 of 5
# Model Number: 105 with model GLM in generation 1 of 5
# Model Number: 106 with model GLM in generation 1 of 5
# Model Number: 107 with model GLM in generation 1 of 5
# Model Number: 108 with model DatepartRegression in generation 1 of 5
# Model Number: 109 with model DatepartRegression in generation 1 of 5
# Model Number: 110 with model DatepartRegression in generation 1 of 5
# Model Number: 111 with model ZeroesNaive in generation 1 of 5
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 112 with model ZeroesNaive in generation 1 of 5
# Model Number: 113 with model ZeroesNaive in generation 1 of 5
# Model Number: 114 with model FBProphet in generation 1 of 5
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 115 with model FBProphet in generation 1 of 5
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 116 with model FBProphet in generation 1 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 116: FBProphet
# Model Number: 117 with model FBProphet in generation 1 of 5
# Model Number: 118 with model GluonTS in generation 1 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 118: GluonTS
# Model Number: 119 with model GluonTS in generation 1 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 119: GluonTS
# Model Number: 120 with model GluonTS in generation 1 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 120: GluonTS
# Model Number: 121 with model GluonTS in generation 1 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 121: GluonTS
# Model Number: 122 with model VAR in generation 1 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 122: VAR
# Model Number: 123 with model VAR in generation 1 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 123: VAR
# Model Number: 124 with model VAR in generation 1 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 124: VAR
# Model Number: 125 with model VAR in generation 1 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 125: VAR
# Model Number: 126 with model VECM in generation 1 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 126: VECM
# Model Number: 127 with model VECM in generation 1 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 127: VECM
# Model Number: 128 with model VECM in generation 1 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 128: VECM
# Model Number: 129 with model VECM in generation 1 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 129: VECM
# New Generation: 2 of 5
# Model Number: 130 with model AverageValueNaive in generation 2 of 5
# Model Number: 131 with model AverageValueNaive in generation 2 of 5
# /usr/local/lib/python3.7/dist-packages/autots/models/sklearn.py:439: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# Model Number: 132 with model AverageValueNaive in generation 2 of 5
# Model Number: 133 with model ETS in generation 2 of 5
# Model Number: 134 with model ETS in generation 2 of 5
# Model Number: 135 with model ETS in generation 2 of 5
# Model Number: 136 with model ETS in generation 2 of 5
# Model Number: 137 with model GLS in generation 2 of 5
# Model Number: 138 with model GLS in generation 2 of 5
# Model Number: 139 with model GLS in generation 2 of 5
# Model Number: 140 with model LastValueNaive in generation 2 of 5
# Model Number: 141 with model LastValueNaive in generation 2 of 5
# Model Number: 142 with model LastValueNaive in generation 2 of 5
# Model Number: 143 with model SeasonalNaive in generation 2 of 5
# Model Number: 144 with model SeasonalNaive in generation 2 of 5
# Model Number: 145 with model SeasonalNaive in generation 2 of 5
# Model Number: 146 with model SeasonalNaive in generation 2 of 5
# Model Number: 147 with model WindowRegression in generation 2 of 5
# Template Eval Error: ValueError("Input contains NaN, infinity or a value too large for dtype('float32').") in model 147: WindowRegression
# Model Number: 148 with model WindowRegression in generation 2 of 5
# Model Number: 149 with model WindowRegression in generation 2 of 5
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:470: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Model Number: 150 with model WindowRegression in generation 2 of 5
# Model Number: 151 with model UnobservedComponents in generation 2 of 5
# Model Number: 152 with model UnobservedComponents in generation 2 of 5
# Model Number: 153 with model UnobservedComponents in generation 2 of 5
# Model Number: 154 with model GLM in generation 2 of 5
# Model Number: 155 with model GLM in generation 2 of 5
# Model Number: 156 with model GLM in generation 2 of 5
# Model Number: 157 with model GLM in generation 2 of 5
# Model Number: 158 with model DatepartRegression in generation 2 of 5
# Model Number: 159 with model DatepartRegression in generation 2 of 5
# Epoch 1/50
# 6/6 [==============================] - 5s 6ms/step - loss: 0.0036
# Epoch 2/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0037
# Epoch 3/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0037
# Epoch 4/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0038
# Epoch 5/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0037
# Epoch 6/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0038
# Epoch 7/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0036
# Epoch 8/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0036
# Epoch 9/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0037
# Epoch 10/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0036
# Epoch 11/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0036
# Epoch 12/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0037
# Epoch 13/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 14/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 15/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0037
# Epoch 16/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0037
# Epoch 17/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 18/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0037
# Epoch 19/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 20/50
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0036
# Epoch 21/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 22/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 23/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0037
# Epoch 24/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 25/50
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0036
# Epoch 26/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0036
# Epoch 27/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0036
# Epoch 28/50
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0036
# Epoch 29/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0036
# Epoch 30/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 31/50
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0037
# Epoch 32/50
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0037
# Epoch 33/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0036
# Epoch 34/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0037
# Epoch 35/50
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0037
# Epoch 36/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0036
# Epoch 37/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 38/50
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0036
# Epoch 39/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 40/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0037
# Epoch 41/50
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0036
# Epoch 42/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0037
# Epoch 43/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0036
# Epoch 44/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0036
# Epoch 45/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0036
# Epoch 46/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0036
# Epoch 47/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0036
# Epoch 48/50
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0036
# Epoch 49/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0036
# Epoch 50/50
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0036
# Model Number: 160 with model DatepartRegression in generation 2 of 5
# Model Number: 161 with model ZeroesNaive in generation 2 of 5
# Model Number: 162 with model ZeroesNaive in generation 2 of 5
# Model Number: 163 with model ZeroesNaive in generation 2 of 5
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 164 with model FBProphet in generation 2 of 5
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 165 with model FBProphet in generation 2 of 5
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 166 with model FBProphet in generation 2 of 5
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 167 with model FBProphet in generation 2 of 5
# Model Number: 168 with model GluonTS in generation 2 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 168: GluonTS
# Model Number: 169 with model GluonTS in generation 2 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 169: GluonTS
# Model Number: 170 with model GluonTS in generation 2 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 170: GluonTS
# Model Number: 171 with model GluonTS in generation 2 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 171: GluonTS
# Model Number: 172 with model VAR in generation 2 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 172: VAR
# Model Number: 173 with model VAR in generation 2 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 173: VAR
# Model Number: 174 with model VAR in generation 2 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 174: VAR
# Model Number: 175 with model VAR in generation 2 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 175: VAR
# Model Number: 176 with model VECM in generation 2 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 176: VECM
# Model Number: 177 with model VECM in generation 2 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 177: VECM
# Model Number: 178 with model VECM in generation 2 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 178: VECM
# Model Number: 179 with model VECM in generation 2 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 179: VECM
# New Generation: 3 of 5
# Model Number: 180 with model AverageValueNaive in generation 3 of 5
# Model Number: 181 with model AverageValueNaive in generation 3 of 5
# Model Number: 182 with model AverageValueNaive in generation 3 of 5
# Model Number: 183 with model ETS in generation 3 of 5
# Model Number: 184 with model ETS in generation 3 of 5
# Model Number: 185 with model ETS in generation 3 of 5
# Model Number: 186 with model ETS in generation 3 of 5
# Model Number: 187 with model GLS in generation 3 of 5
# Model Number: 188 with model GLS in generation 3 of 5
# Model Number: 189 with model GLS in generation 3 of 5
# Model Number: 190 with model LastValueNaive in generation 3 of 5
# Model Number: 191 with model LastValueNaive in generation 3 of 5
# Model Number: 192 with model LastValueNaive in generation 3 of 5
# Model Number: 193 with model UnobservedComponents in generation 3 of 5
# Model Number: 194 with model UnobservedComponents in generation 3 of 5
# Model Number: 195 with model UnobservedComponents in generation 3 of 5
# Model Number: 196 with model SeasonalNaive in generation 3 of 5
# Model Number: 197 with model SeasonalNaive in generation 3 of 5
# Model Number: 198 with model SeasonalNaive in generation 3 of 5
# Model Number: 199 with model SeasonalNaive in generation 3 of 5
# Model Number: 200 with model DatepartRegression in generation 3 of 5
# Model Number: 201 with model DatepartRegression in generation 3 of 5
# Model Number: 202 with model DatepartRegression in generation 3 of 5
# Model Number: 203 with model WindowRegression in generation 3 of 5
# Model Number: 204 with model WindowRegression in generation 3 of 5
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:470: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Model Number: 205 with model WindowRegression in generation 3 of 5
# Model Number: 206 with model WindowRegression in generation 3 of 5
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:470: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/families/family.py:1440: RuntimeWarning:
#
# invalid value encountered in log
# Model Number: 207 with model GLM in generation 3 of 5
# Model Number: 208 with model GLM in generation 3 of 5
# Template Eval Error: ValueError('The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.') in model 208: GLM
# Model Number: 209 with model GLM in generation 3 of 5
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 210 with model ZeroesNaive in generation 3 of 5
# Model Number: 211 with model ZeroesNaive in generation 3 of 5
# Model Number: 212 with model FBProphet in generation 3 of 5
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 213 with model FBProphet in generation 3 of 5
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 214 with model FBProphet in generation 3 of 5
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 215 with model FBProphet in generation 3 of 5
# Model Number: 216 with model GluonTS in generation 3 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 216: GluonTS
# Model Number: 217 with model GluonTS in generation 3 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 217: GluonTS
# Model Number: 218 with model GluonTS in generation 3 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 218: GluonTS
# Model Number: 219 with model GluonTS in generation 3 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 219: GluonTS
# Model Number: 220 with model VAR in generation 3 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 220: VAR
# Model Number: 221 with model VAR in generation 3 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 221: VAR
# Model Number: 222 with model VAR in generation 3 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 222: VAR
# Model Number: 223 with model VAR in generation 3 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 223: VAR
# Model Number: 224 with model VECM in generation 3 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 224: VECM
# Model Number: 225 with model VECM in generation 3 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 225: VECM
# Model Number: 226 with model VECM in generation 3 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 226: VECM
# Model Number: 227 with model VECM in generation 3 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 227: VECM
# New Generation: 4 of 5
# Model Number: 228 with model AverageValueNaive in generation 4 of 5
# Model Number: 229 with model AverageValueNaive in generation 4 of 5
# /usr/local/lib/python3.7/dist-packages/autots/models/sklearn.py:376: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# Model Number: 230 with model AverageValueNaive in generation 4 of 5
# Model Number: 231 with model GLS in generation 4 of 5
# Model Number: 232 with model GLS in generation 4 of 5
# Model Number: 233 with model ETS in generation 4 of 5
# Model Number: 234 with model ETS in generation 4 of 5
# Model Number: 235 with model ETS in generation 4 of 5
# Model Number: 236 with model ETS in generation 4 of 5
# Model Number: 237 with model LastValueNaive in generation 4 of 5
# Model Number: 238 with model LastValueNaive in generation 4 of 5
# Model Number: 239 with model LastValueNaive in generation 4 of 5
# Model Number: 240 with model UnobservedComponents in generation 4 of 5
# Model Number: 241 with model UnobservedComponents in generation 4 of 5
# Model Number: 242 with model UnobservedComponents in generation 4 of 5
# Model Number: 243 with model SeasonalNaive in generation 4 of 5
# Model Number: 244 with model SeasonalNaive in generation 4 of 5
# Model Number: 245 with model SeasonalNaive in generation 4 of 5
# Model Number: 246 with model SeasonalNaive in generation 4 of 5
# Model Number: 247 with model WindowRegression in generation 4 of 5
# Template Eval Error: ValueError('at least one array or dtype is required') in model 247: WindowRegression
# Model Number: 248 with model WindowRegression in generation 4 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 248: WindowRegression
# Model Number: 249 with model WindowRegression in generation 4 of 5
# Template Eval Error: ValueError("Input contains NaN, infinity or a value too large for dtype('float64').") in model 249: WindowRegression
# Model Number: 250 with model WindowRegression in generation 4 of 5
# Model Number: 251 with model DatepartRegression in generation 4 of 5
# Model Number: 252 with model DatepartRegression in generation 4 of 5
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# Model Number: 253 with model DatepartRegression in generation 4 of 5
# Model Number: 254 with model GLM in generation 4 of 5
# Model Number: 255 with model GLM in generation 4 of 5
# Template Eval Error: ValueError('NaN, inf or invalid value detected in weights, estimation infeasible.') in model 255: GLM
# Model Number: 256 with model GLM in generation 4 of 5
# Model Number: 257 with model GLM in generation 4 of 5
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/families/family.py:1440: RuntimeWarning:
#
# invalid value encountered in log
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/families/family.py:1440: RuntimeWarning:
#
# divide by zero encountered in true_divide
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/generalized_linear_model.py:774: RuntimeWarning:
#
# divide by zero encountered in true_divide
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/families/family.py:134: RuntimeWarning:
#
# divide by zero encountered in true_divide
#
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 258 with model ZeroesNaive in generation 4 of 5
# Model Number: 259 with model ZeroesNaive in generation 4 of 5
# Model Number: 260 with model ZeroesNaive in generation 4 of 5
# Model Number: 261 with model FBProphet in generation 4 of 5
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Model Number: 262 with model FBProphet in generation 4 of 5
# Model Number: 263 with model GluonTS in generation 4 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 263: GluonTS
# Model Number: 264 with model GluonTS in generation 4 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 264: GluonTS
# Model Number: 265 with model GluonTS in generation 4 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 265: GluonTS
# Model Number: 266 with model GluonTS in generation 4 of 5
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 266: GluonTS
# Model Number: 267 with model VAR in generation 4 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 267: VAR
# Model Number: 268 with model VAR in generation 4 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 268: VAR
# Model Number: 269 with model VAR in generation 4 of 5
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 269: VAR
# Model Number: 270 with model VECM in generation 4 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 270: VECM
# Model Number: 271 with model VECM in generation 4 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 271: VECM
# Model Number: 272 with model VECM in generation 4 of 5
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 272: VECM
# Model Number: 273 with model VECM in generation 4 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 273: VECM
# New Generation: 5 of 5
# Model Number: 274 with model ETS in generation 5 of 5
# Model Number: 275 with model ETS in generation 5 of 5
# Model Number: 276 with model ETS in generation 5 of 5
# Model Number: 277 with model ETS in generation 5 of 5
# Model Number: 278 with model AverageValueNaive in generation 5 of 5
# Template Eval Error: ValueError('Cannot convert non-finite values (NA or inf) to integer') in model 278: AverageValueNaive
# Model Number: 279 with model AverageValueNaive in generation 5 of 5
# Model Number: 280 with model AverageValueNaive in generation 5 of 5
# Model Number: 281 with model GLS in generation 5 of 5
# Model Number: 282 with model GLS in generation 5 of 5
# Model Number: 283 with model GLS in generation 5 of 5
# Model Number: 284 with model LastValueNaive in generation 5 of 5
# Model Number: 285 with model LastValueNaive in generation 5 of 5
# Model Number: 286 with model LastValueNaive in generation 5 of 5
# Model Number: 287 with model WindowRegression in generation 5 of 5
# Model Number: 288 with model WindowRegression in generation 5 of 5
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# Template Eval Error: ValueError("Input contains NaN, infinity or a value too large for dtype('float64').") in model 288: WindowRegression
# Model Number: 289 with model WindowRegression in generation 5 of 5
# Template Eval Error: ValueError('Unable to coerce to Series, length must be 1: given 190') in model 289: WindowRegression
# Model Number: 290 with model WindowRegression in generation 5 of 5
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning:
#
# ...
# Model Number: 13 of 49 with model LastValueNaive for Validation 2
# Model Number: 14 of 49 with model LastValueNaive for Validation 2
# Model Number: 15 of 49 with model LastValueNaive for Validation 2
# Model Number: 16 of 49 with model LastValueNaive for Validation 2
# Model Number: 17 of 49 with model ETS for Validation 2
# Model Number: 18 of 49 with model ETS for Validation 2
# Model Number: 19 of 49 with model WindowRegression for Validation 2
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:470: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Model Number: 20 of 49 with model UnobservedComponents for Validation 2
# Model Number: 21 of 49 with model SeasonalNaive for Validation 2
# Model Number: 22 of 49 with model WindowRegression for Validation 2
# Model Number: 23 of 49 with model SeasonalNaive for Validation 2
# Model Number: 24 of 49 with model ETS for Validation 2
# Model Number: 25 of 49 with model SeasonalNaive for Validation 2
# Model Number: 26 of 49 with model SeasonalNaive for Validation 2
# Model Number: 27 of 49 with model SeasonalNaive for Validation 2
# Model Number: 28 of 49 with model DatepartRegression for Validation 2
# Model Number: 29 of 49 with model DatepartRegression for Validation 2
# [LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear]
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
# [LibLinear][LibLinear][LibLinear][LibLinear][LibLinear]Model Number: 30 of 49 with model WindowRegression for Validation 2
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
# Model Number: 31 of 49 with model WindowRegression for Validation 2
# [LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear]
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
# [LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear]
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
# [LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear]Model Number: 32 of 49 with model UnobservedComponents for Validation 2
# Model Number: 33 of 49 with model AverageValueNaive for Validation 2
# Model Number: 34 of 49 with model AverageValueNaive for Validation 2
# Model Number: 35 of 49 with model DatepartRegression for Validation 2
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
# Epoch 1/50
# 4/4 [==============================] - 6s 7ms/step - loss: 0.0080
# Epoch 2/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0081
# Epoch 3/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0080
# Epoch 4/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0081
# Epoch 5/50
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0080
# Epoch 6/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0081
# Epoch 7/50
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0077
# Epoch 8/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0080
# Epoch 9/50
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0079
# Epoch 10/50
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0078
# Epoch 11/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0081
# Epoch 12/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0079
# Epoch 13/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0080
# Epoch 14/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0080
# Epoch 15/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0079
# Epoch 16/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0079
# Epoch 17/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0078
# Epoch 18/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0078
# Epoch 19/50
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0080
# Epoch 20/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0078
# Epoch 21/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0080
# Epoch 22/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0080
# Epoch 23/50
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0079
# Epoch 24/50
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0078
# Epoch 25/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0079
# Epoch 26/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0080
# Epoch 27/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0080
# Epoch 28/50
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0079
# Epoch 29/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0079
# Epoch 30/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0082
# Epoch 31/50
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0080
# Epoch 32/50
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0082
# Epoch 33/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0082
# Epoch 34/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0080
# Epoch 35/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0079
# Epoch 36/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0081
# Epoch 37/50
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0079
# Epoch 38/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0080
# Epoch 39/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0081
# Epoch 40/50
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0080
# Epoch 41/50
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0081
# Epoch 42/50
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0080
# Epoch 43/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0082
# Epoch 44/50
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0079
# Epoch 45/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0080
# Epoch 46/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0080
# Epoch 47/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0079
# Epoch 48/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0080
# Epoch 49/50
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0079
# Epoch 50/50
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0079
# Model Number: 36 of 49 with model DatepartRegression for Validation 2
# Model Number: 37 of 49 with model GLM for Validation 2
# Model Number: 38 of 49 with model GLM for Validation 2
# Model Number: 39 of 49 with model GLM for Validation 2
# Model Number: 40 of 49 with model GLM for Validation 2
# Model Number: 41 of 49 with model DatepartRegression for Validation 2
# Model Number: 42 of 49 with model UnobservedComponents for Validation 2
# Model Number: 43 of 49 with model ZeroesNaive for Validation 2
# Model Number: 44 of 49 with model WindowRegression for Validation 2
# Model Number: 45 of 49 with model ZeroesNaive for Validation 2
# Model Number: 46 of 49 with model ZeroesNaive for Validation 2
# Model Number: 47 of 49 with model AverageValueNaive for Validation 2
# Model Number: 48 of 49 with model AverageValueNaive for Validation 2
# Model Number: 49 of 49 with model UnobservedComponents for Validation 2
# DogeCoin Price Prediction
#                Close
# 2021-07-02  0.245141
# 2021-07-03  0.246879
# 2021-07-04  0.251207
# 2021-07-05  0.252177
# 2021-07-06  0.252363
# 2021-07-07  0.252614
# 2021-07-08  0.257772
# 2021-07-09  0.260478
# 2021-07-10  0.262084
# 2021-07-11  0.266571
